// %% [markdown]
// # Prueba

// %% [markdown]
// ![spring_initializr](data:image/png;base64,...)

// %%
public class Prueba{
    @Id
    
    private Long id;
}
// Out:
// |   public class Prueba{
// |       @Id
// |
// |       private Long id;
// |   }
// Unresolved dependencies:
//    - class Id
